# %% [markdown]
# ### Set up

# %%
! git clone https://github.com/irdinss/gamuda-defect-segmentation.git
# %cd /[Google COlab/Lightning AI/ Kaggle/etc file_directory]/gamuda-defect-segmentation
# !git branch
# !git pull

# %% [markdown]
# ### Run training

# %%
# !python -m scripts.train_segformer --data_dir [PATH TO DATA FOLDER]

# %% [markdown]
# ### Evaluate training output

# %%
# !python -m scripts.evaluate --data_dir [PATH TO DATA FOLDER]

# %% [markdown]
# ### View Prediction output (Image Overlay & Prediction Mask)

# %%
# !python -m scripts.predict --image [IMAGE PATH]
